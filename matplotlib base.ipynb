# %%
# %matplotlib nbagg

# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
s = pd.Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))
s
# Out:
# 0     0.921744
# 10    1.954115
# 20    1.109244
# 30    1.015894
# 40    2.061267
# 50    4.605002
# 60    5.059813
# 70    7.180654
# 80    6.580063
# 90    6.832318
# dtype: float64

# %%
s.plot()
# plt.plot(s)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
df = pd.DataFrame(np.random.randn(10, 4).cumsum(axis=0),
                  columns=["A", "B", "C", "D"],
                  index=np.arange(0, 100, 10))

# %%
df
# Out:
#            A         B         C         D
# 0   0.660142  0.669351 -0.165371 -0.608064
# 10  0.628838 -1.329704 -1.021926 -1.581245
# 20  0.590309 -2.234354 -2.221784 -2.707061
# 30 -1.074992 -2.867841 -2.414912 -3.636952
# 40 -0.431709 -2.866076 -1.200685 -4.894114
# 50 -0.267642 -2.546527 -1.003986 -5.196761
# 60  0.628848 -3.304843 -2.464052 -6.239777
# 70  1.443428 -3.996456 -1.390749 -6.067232
# 80  1.914099 -2.299588 -0.419121 -6.185175
# 90  0.103589 -0.696918 -0.591674 -5.426202

# %%
df.plot()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
df["B"].plot()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
s2 = pd.Series(np.random.rand(16), index=list("abcdefghijklmnop"))

# %%
s2.plot(kind="bar")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
s2
# Out:
# a    0.593348
# b    0.430530
# c    0.755321
# d    0.308168
# e    0.573781
# f    0.642918
# g    0.452519
# h    0.597359
# i    0.083088
# j    0.162704
# k    0.841218
# l    0.420087
# m    0.254987
# n    0.563827
# o    0.965281
# p    0.754629
# dtype: float64

# %%
s2.plot(kind="bar")
#수직방향 bar
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
s2.plot(kind="barh")
#수평방향 bar
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
df2 = pd.DataFrame(np.random.rand(6, 4), 
                   index=["one", "two", "three", "four", "five", "six"],
                   columns=pd.Index(["A", "B", "C", "D"], name="Genus"))
df
# Out:
#            A         B         C         D
# 0   0.660142  0.669351 -0.165371 -0.608064
# 10  0.628838 -1.329704 -1.021926 -1.581245
# 20  0.590309 -2.234354 -2.221784 -2.707061
# 30 -1.074992 -2.867841 -2.414912 -3.636952
# 40 -0.431709 -2.866076 -1.200685 -4.894114
# 50 -0.267642 -2.546527 -1.003986 -5.196761
# 60  0.628848 -3.304843 -2.464052 -6.239777
# 70  1.443428 -3.996456 -1.390749 -6.067232
# 80  1.914099 -2.299588 -0.419121 -6.185175
# 90  0.103589 -0.696918 -0.591674 -5.426202

# %%
df2.plot(kind="bar")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
df2.plot(kind="barh", stacked=True)
#수평방향으로 그래프를 쌓아서 올림
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
s3 = pd.Series(np.random.normal(0, 1, size=200))

# %%
s3
# Out:
# 0     -0.413800
# 1      0.026477
# 2     -2.204987
# 3     -1.700649
# 4      0.665911
# 5     -1.936089
# 6     -1.114608
# 7     -1.738483
# 8     -1.307992
# 9     -0.541487
# 10    -0.542147
# 11    -0.604919
# 12     1.005773
# 13    -0.772995
# 14    -0.456165
# 15    -1.060568
# 16     0.206331
# 17     1.798311
# 18    -0.803279
# 19     1.007666
# 20    -0.666796
# 21    -1.904415
# 22     0.831317
# 23    -0.322596
# 24    -0.029025
# 25     0.414097
# 26    -0.344544
# 27    -0.310149
# 28     0.056097
# 29    -0.547663
#          ...
# 170   -2.068095
# 171    1.699924
# 172   -0.639007
# 173   -1.176483
# 174   -1.364426
# 175   -0.430161
# 176   -0.947057
# 177    0.512295
# 178   -0.418412
# 179   -0.666717
# 180    0.138379
# 181   -1.584102
# 182   -0.672840
# 183   -1.793044
# 184   -0.393792
# 185   -0.120748
# 186    1.589877
# 187   -0.651268
# 188    0.542136
# 189   -0.161701
# 190   -0.147241
# 191   -0.111517
# 192    2.043758
# 193   -0.991581
# 194   -0.202187
# 195   -1.489739
# 196   -1.125959
# 197   -1.295943
# 198   -1.929828
# 199    1.099879
# dtype: float64

# %%
s3.hist()
#히스토그램을 그린다
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
s3.hist(bins=50)
#구간의 갯수를 증가 시킨다
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
s3.hist(bins=100, normed=True)
#정규화한 내용을 표시해 준다
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
x1 = np.random.normal(1, 1, size=(100, 1))
x2 = np.random.normal(-2, 4, size=(100, 1))
X = np.concatenate((x1, x2), axis=1)

# %%
X
# Out:
# array([[  0.92577265,   0.25751364],
#        [  0.25176333,  -3.49967963],
#        [  1.74504136,  -4.24423983],
#        [  1.23971591,  -1.29759675],
#        [ -0.85696823,  -0.81750423],
#        [  1.15571782,  -4.91371261],
#        [  0.35727276,   0.16059813],
#        [  0.4482416 ,  -5.739588  ],
#        [  1.81646708,  -2.93821211],
#        [  2.96169377,   1.93414181],
#        [  2.10629621,  -1.75102535],
#        [  0.70353503,  -1.84662087],
#        [  0.57443367,   3.46307551],
#        [  0.12293992,  -1.91558311],
#        [  1.81611707,  -1.97450632],
#        [  0.48980312,   4.59034762],
#        [  1.56099933,  -0.16481532],
#        [  0.31155562,  -0.14019469],
#        [  1.16628441,   5.96949771],
#        [  1.30598241,  -2.44581377],
#        [  0.46359992,   1.97643883],
#        [  1.07855705,  -3.82338592],
#        [  2.41990334,  -3.54823261],
#        [  0.643973  ,  -2.17664577],
#        [  1.68443364,  -5.97233044],
#        [  1.11062936,  -6.89806443],
#        [ -1.11975214,  -2.16593597],
#        [  1.24808065,  -2.20152697],
#        [ -0.7506121 ,   7.04154188],
#        [  1.73233327,  -6.19877486],
#        [  1.48378009, -13.50332297],
#        [  1.77308526,   2.76934444],
#        [  0.2811603 ,  -1.44808821],
#        [  0.50982405,   2.29919723],
#        [  0.56869719,  -0.96675471],
#        [  1.05904307,  -7.93169929],
#        [  0.04849896,   0.29682087],
#        [  1.19275319,  -7.65277321],
#        [ -1.34817003,  -8.8302779 ],
#        [  2.844059  ,  -5.59747029],
#        [ -0.77002367,   2.4431299 ],
#        [  1.63418684,  -1.70174688],
#        [  2.54714899,  -1.22809933],
#        [  2.05784963,   0.61445687],
#        [  0.34418621,  -5.08502536],
#        [  0.77143776,  -1.11953948],
#        [  0.19263703,  -3.92388137],
#        [ -0.4404901 ,  -2.26251544],
#        [ -0.2218303 ,  -6.05432196],
#        [ -0.53137344,  -5.07563165],
#        [  1.08650455,   4.76523177],
#        [  0.97908013,  -1.06556886],
#        [  1.87681168,  -3.66567935],
#        [  1.3659282 ,  -6.50091107],
#        [ -0.02035193,  -2.80368341],
#        [ -0.15360855,  -7.08869288],
#        [ -0.45059726,   1.92026642],
#        [  0.5234864 ,  -3.71656742],
#        [  1.48767473,   2.05269687],
#        [ -0.61048825,   1.93768811],
#        [  2.53168624,   2.2459949 ],
#        [  2.04383092,  -3.1464559 ],
#        [ -0.22319137,   2.91051249],
#        [  2.11257532,  -4.74978913],
#        [  2.88794742,   6.854308  ],
#        [  0.83863762,   1.53408336],
#        [  0.942443  ,  -2.45431549],
#        [  0.53833717,  -3.6172174 ],
#        [  0.36718102,  -1.82416213],
#        [  2.66565161,  -5.99844113],
#        [  1.87833352,  -5.86359167],
#        [  1.48629102,  -2.33075121],
#        [  1.47920498,  -2.57231421],
#        [  0.73905712,  -2.11054402],
#        [  2.22788515,   7.11218694],
#        [  1.32194287,  -1.03609279],
#        [ -0.703839  ,   2.08713582],
#        [  1.59804738,  -6.97896529],
#        [  2.44038152,  -1.33252839],
#        [  0.25690469, -12.08941312],
#        [  0.35925703,  -2.10740277],
#        [  1.04088615,  -7.21927371],
#        [  1.1095756 ,  -5.3793858 ],
#        [  2.75124772,   0.24765735],
#        [ -0.08125742,  -3.1442064 ],
#        [  0.73109761,  -1.04109464],
#        [  1.27682623,  -8.90924664],
#        [  1.65639546,  -1.26955365],
#        [ -0.8335021 ,  -0.13608131],
#        [ -0.73294072,  -2.0120052 ],
#        [  2.95316193,   0.48536045],
#        [  0.89524398,   3.75004056],
#        [  3.18285435,  -8.26301977],
#        [ -0.53236569,  -7.27551104],
#        [  0.07302923, -11.49241375],
#        [ -0.16626371,  -2.34006141],
#        [  0.96109896,  -7.24988314],
#        [ -0.01769903,  -3.02757609],
#        [  0.82323565,   2.7420421 ],
#        [ -0.40792928,  -0.1354531 ]])

# %%
df3 = pd.DataFrame(X, columns=["x1", "x2"])

# %%
df3

# %%
plt.scatter(df3["x1"], df3["x2"])
#산점도 그리기
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

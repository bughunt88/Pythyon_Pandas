# %%
# %matplotlib nbagg
import matplotlib
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
ax1 = fig.add_subplot(2,2,1)
#2x2 칸을 만들고 1번 위치에 그린다

# %%
ax2 = fig.add_subplot(2,2,2)
#2x2 칸을 만들고 2 위치에 그린다

# %%
ax3 = fig.add_subplot(2,2,3)
#2x2 칸을 만들고 3 위치에 그린다

# %%
import pandas as pd
import numpy as np

# %%
plt.plot(np.random.randn(50).cumsum())

# %%
ax1.hist(np.random.randn(100), bins=20)
# Out:
# (array([  1.,   0.,   1.,   4.,   1.,   4.,   6.,   4.,   7.,  12.,   8.,
#          10.,   8.,  11.,   7.,   3.,   2.,   5.,   4.,   2.]),
#  array([-2.46753761, -2.23619757, -2.00485752, -1.77351748, -1.54217743,
#         -1.31083739, -1.07949734, -0.8481573 , -0.61681725, -0.38547721,
#         -0.15413716,  0.07720288,  0.30854293,  0.53988297,  0.77122302,
#          1.00256306,  1.23390311,  1.46524316,  1.6965832 ,  1.92792325,
#          2.15926329]),
#  <a list of 20 Patch objects>)

# %%
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))

# %%
fig, axes = plt.subplots(2,3)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000009C3C320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000009CF5D30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000009D63278>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000000009DB4A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000009E1CDD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000009E76908>]], dtype=object)

# %%
plt.plot(np.random.randn(30), color="g", marker='o', linestyle="--")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
plt.plot(np.random.randn(30), "k.-")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
fig, axes = plt.subplots(2, 1)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
data = pd.Series(np.random.rand(16), index=list('abcdefghijklmnop'))

# %%
data.plot(kind="bar", ax=axes[0], color='k', alpha=0.7)

# %%
data.plot(kind="barh", ax=axes[1], color='g', alpha=0.3)

# %%
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
ax = fig.add_subplot(1,1,1)

# %%
ax.plot(np.random.randn(1000).cumsum())

# %%
ticks = ax.set_xticks([0, 250, 500, 750, 1000])
#플롯의 수평축 눈금을 수정하는 코드

# %%
labels = ax.set_xticklabels(["one", "two", "three", "four", "five"],
                            rotation=30, fontsize="small")

# %%
ax.set_title("Random walk plot")
#타이틀 만들기

# %%
ax.set_xlabel("Stages")
ax.set_ylabel("Values")
#축 이름 만들기

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
ax.plot(np.random.randn(1000).cumsum(), 'k', label="one")
ax.plot(np.random.randn(1000).cumsum(), "b--", label="two")
ax.plot(np.random.randn(1000).cumsum(), "r.", label="three")

# %%
ax.legend(loc="best")
#범례를 만들기

# %%
ax.get_xlim()
# Out:
# (-49.950000000000003, 1048.95)

# %%
ax.set_xlim([100,900])
#x축 범위 변경
# Out:
# (100, 900)

# %%
ax.set_ylim([-100,100])
#y축 범위 변경
# Out:
# (-100, 100)
